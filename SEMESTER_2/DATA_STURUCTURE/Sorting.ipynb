# %% [markdown]
# Merge Sort

# %% [markdown]
# Q1-https://leetcode.com/problems/sort-an-array/

# %% [markdown]
# Q2-https://leetcode.com/problems/count-of-smaller-numbers-after-self/

# %% [markdown]
# Q3-https://leetcode.com/problems/reverse-pairs/

# %% [markdown]
# q4-https://leetcode.com/problems/count-of-range-sum/

# %% [markdown]
# Q5-https://leetcode.com/problems/merge-intervals/
